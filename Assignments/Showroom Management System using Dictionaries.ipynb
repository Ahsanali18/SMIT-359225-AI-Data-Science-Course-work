# %%
"""
Task#:5
Create a console based vehicle showroom application in whyich at least 3 vehicle companies are registered and every company have 3 cars and 
every car has details (price, name, model, year).
Create an applicaton who takes company as an input and shows it's cars as a menu then it ask for the car name as an input and shows the 
complete details as an ouput.
                                                    Note: Make use of dictionaries """

showroom={
    "Honda":{
     "Civic":{"model":"Rs Turbo","year":2023,"price":"$29,000"},
     "City": {"model":"Aspire 1.5","year":2022,"price":"$21,000"},
     "CR-V": {"model":"AWD Touring","year":2023,"price":"$34,000"}
    },
    "Toyota":{
    "Corolla":{"model":"Altis Grande","year":2023,"price":"$24,000"},
    "Yaris":{"model":"ATIV X","year":2022,"price":"$19,000"},
    "Hilux":{"model":"Revo V","year":2023,"price":"$40,000"}
    },
    "Suzuki":{
    "Swift":{"model":"GLX CTV","year":2023,"price":"$16,000"},
    "Alto":{"model":"VXR","year":2022,"price":"$10,000"},
    "Cultus":{"model":"VXL","year":2023,"price":"14,0000"}
    }
}

# Menu to show company names
print("------------ Welcome to Prince Showroom ------------")
print("Available Companies")
print("1.Honda")
print("2.Toyota")
print("3.Suzuki")
print("====================================================")

company_name=input("Enter company name: ")

if company_name=="Honda":
    print("Available cars of Honda company")
    print("Civic")
    print("City")
    print("CR-V")
    
    selected_car=input("Enter car name: ")
    if selected_car == "Civic":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Honda"]["Civic"]["model"])
        print("Year: ",showroom["Honda"]["Civic"]["year"])
        print("Price: ",showroom["Honda"]["Civic"]["price"])
    elif selected_car=="City":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Honda"]["City"]["model"])
        print("Year: ",showroom["Honda"]["City"]["year"])
        print("Price: ",showroom["Honda"]["City"]["price"])
    elif selected_car=="CR-V":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Honda"]["CR-V"]["model"])
        print("Year: ",showroom["Honda"]["CR-V"]["year"])
        print("Price: ",showroom["Honda"]["CR-V"]["price"])
    else:
        print("Invalid Car Name!")

        
elif company_name=="Toyota":
    print("Available cars of Toyota company")
    print("Corolla")
    print("Yaris")
    print("Hilux")
    
    selected_car=input("Enter car name: ")
    if selected_car == "Corolla":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Toyota"]["Corolla"]["model"])
        print("Year: ",showroom["Toyota"]["Corolla"]["year"])
        print("Price: ",showroom["Toyota"]["Corolla"]["price"])
    elif selected_car=="Yaris":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Toyota"]["Yaris"]["model"])
        print("Year: ",showroom["Toyota"]["Yaris"]["year"])
        print("Price: ",showroom["Toyota"]["Yaris"]["price"])
    elif selected_car=="Hilux":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Toyota"]["Hilux"]["model"])
        print("Year: ",showroom["Toyota"]["Hilux"]["year"])
        print("Price: ",showroom["Toyota"]["Hilux"]["price"])
    else:
        print("Invalid Car Name!")

elif company_name=="Suzuki":
    print("Available cars of Suzuki company")
    print("Swift")
    print("Alto")
    print("Cultus")
    
    selected_car=input("Enter car name: ")
    if selected_car == "Swift":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Suzuki"]["Swift"]["model"])
        print("Year: ",showroom["Suzuki"]["Swift"]["year"])
        print("Price: ",showroom["Suzuki"]["Swift"]["price"])
    elif selected_car=="Alto":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Suzuki"]["Alto"]["model"])
        print("Year: ",showroom["Suzuki"]["Alto"]["year"])
        print("Price: ",showroom["Suzuki"]["Alto"]["price"])
    elif selected_car=="Cultus":
        print("Car Name: ",selected_car)
        print("Model: ",showroom["Suzuki"]["Cultus"]["model"])
        print("Year: ",showroom["Suzuki"]["Cultus"]["year"])
        print("Price: ",showroom["Suzuki"]["Cultus"]["price"])
    else:
        print("Invalid Car Name!")

else:
    print("Sorry, This company is not available at our showroom!")
# Out:
# ------------ Welcome to Prince Showroom ------------
# Available Companies
# 1.Honda
# 2.Toyota
# 3.Suzuki
# ...
# Enter company name:  www
# Sorry, This company is not available at our showroom!
